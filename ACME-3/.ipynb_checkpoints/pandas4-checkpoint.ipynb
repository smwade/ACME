# %% [markdown]
# # Pandas 4
# Sean Wade

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn

# %%
# %matplotlib inline

# %% [markdown]
# ## Problem 1

# %%
DJIA = pd.Series.from_csv('DJIA.csv')
DJIA = DJIA.replace(to_replace='.', value=np.nan)
DJIA = DJIA[1:].astype(np.float64)
DJIA.index = pd.to_datetime(DJIA.index)
DJIA.head()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-4-ffd3e52dc8ad> in <module>()
# ----> 1 DJIA = pd.Series.from_csv('DJIA.csv')
#       2 DJIA = DJIA.replace(to_replace='.', value=np.nan)
#       3 DJIA = DJIA[1:].astype(np.float64)
#       4 DJIA.index = pd.to_datetime(DJIA.index)
#       5 DJIA.head()
#
# //anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in from_csv(cls, path, sep, parse_dates, header, index_col, encoding, infer_datetime_format)
#    2570                                 sep=sep, parse_dates=parse_dates,
#    2571                                 encoding=encoding,
# -> 2572                                 infer_datetime_format=infer_datetime_format)
#    2573         result = df.iloc[:, 0]
#    2574         if header is None:
#
# //anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in from_csv(cls, path, header, sep, index_col, parse_dates, encoding, tupleize_cols, infer_datetime_format)
#    1229                           parse_dates=parse_dates, index_col=index_col,
#    1230                           encoding=encoding, tupleize_cols=tupleize_cols,
# -> 1231                           infer_datetime_format=infer_datetime_format)
#    1232
#    1233     def to_sparse(self, fill_value=None, kind='block'):
#
# //anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     643                     skip_blank_lines=skip_blank_lines)
#     644
# --> 645         return _read(filepath_or_buffer, kwds)
#     646
#     647     parser_f.__name__ = name
#
# //anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     386
#     387     # Create the parser.
# --> 388     parser = TextFileReader(filepath_or_buffer, **kwds)
#     389
#     390     if (nrows is not None) and (chunksize is not None):
#
# //anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     727             self.options['has_index_names'] = kwds['has_index_names']
#     728
# --> 729         self._make_engine(self.engine)
#     730
#     731     def close(self):
#
# //anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     920     def _make_engine(self, engine='c'):
#     921         if engine == 'c':
# --> 922             self._engine = CParserWrapper(self.f, **self.options)
#     923         else:
#     924             if engine == 'python':
#
# //anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1387         kwds['allow_leading_cols'] = self.index_col is not False
#    1388
# -> 1389         self._reader = _parser.TextReader(src, **kwds)
#    1390
#    1391         # XXX
#
# pandas/parser.pyx in pandas.parser.TextReader.__cinit__ (pandas/parser.c:4175)()
#
# pandas/parser.pyx in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:8440)()
#
# IOError: File DJIA.csv does not exist

# %%
#DJIA = pd.read_csv('DJIA.csv', index_col=0)
#DJIA = DJIA.convert_objects(convert_numeric=True)
#DJIA.index = pd.to_datetime(DJIA.index)
#DJIA.head()

# %% [markdown]
# ## Problem 2

# %%
payData = pd.Series.from_csv('paychecks.csv', index_col=False)
dateTime1 = pd.date_range(start='3/13/2008', periods=94/2, freq="WOM-3FRI" )
dateTime2 = pd.date_range(start='3/13/2008', periods=94/2, freq="WOM-1FRI" )
timeIndex = dateTime1.union(dateTime2)[:93]
paySeries = pd.Series(payData.values, index=timeIndex)
paySeries = paySeries.astype(np.float64)
paySeries.plot(title="Paychecks"); plt.show()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-6-5c6a9633de4d> in <module>()
# ----> 1 payData = pd.Series.from_csv('paychecks.csv', index_col=False)
#       2 dateTime1 = pd.date_range(start='3/13/2008', periods=94/2, freq="WOM-3FRI" )
#       3 dateTime2 = pd.date_range(start='3/13/2008', periods=94/2, freq="WOM-1FRI" )
#       4 timeIndex = dateTime1.union(dateTime2)[:93]
#       5 paySeries = pd.Series(payData.values, index=timeIndex)
#
# //anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in from_csv(cls, path, sep, parse_dates, header, index_col, encoding, infer_datetime_format)
#    2570                                 sep=sep, parse_dates=parse_dates,
#    2571                                 encoding=encoding,
# -> 2572                                 infer_datetime_format=infer_datetime_format)
#    2573         result = df.iloc[:, 0]
#    2574         if header is None:
#
# //anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in from_csv(cls, path, header, sep, index_col, parse_dates, encoding, tupleize_cols, infer_datetime_format)
#    1229                           parse_dates=parse_dates, index_col=index_col,
#    1230                           encoding=encoding, tupleize_cols=tupleize_cols,
# -> 1231                           infer_datetime_format=infer_datetime_format)
#    1232
#    1233     def to_sparse(self, fill_value=None, kind='block'):
#
# //anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     643                     skip_blank_lines=skip_blank_lines)
#     644
# --> 645         return _read(filepath_or_buffer, kwds)
#     646
#     647     parser_f.__name__ = name
#
# //anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     386
#     387     # Create the parser.
# --> 388     parser = TextFileReader(filepath_or_buffer, **kwds)
#     389
#     390     if (nrows is not None) and (chunksize is not None):
#
# //anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     727             self.options['has_index_names'] = kwds['has_index_names']
#     728
# --> 729         self._make_engine(self.engine)
#     730
#     731     def close(self):
#
# //anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     920     def _make_engine(self, engine='c'):
#     921         if engine == 'c':
# --> 922             self._engine = CParserWrapper(self.f, **self.options)
#     923         else:
#     924             if engine == 'python':
#
# //anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1387         kwds['allow_leading_cols'] = self.index_col is not False
#    1388
# -> 1389         self._reader = _parser.TextReader(src, **kwds)
#    1390
#    1391         # XXX
#
# pandas/parser.pyx in pandas.parser.TextReader.__cinit__ (pandas/parser.c:4175)()
#
# pandas/parser.pyx in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:8440)()
#
# IOError: File paychecks.csv does not exist

# %% [markdown]
# ## Problem 3

# %%
DJIA.plot(title="Dow Jones Industrial Average")
plt.xlabel("Date"); plt.ylabel("Value (dollars)")
plt.show()

# %% [markdown]
# ## Problem 4

# %%
finances = pd.read_csv('finances.csv')
finances.index = pd.period_range(start='1978-09', end='2016-10', freq='Q-SEP')[1:84]
finances.head()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-1-173572308707> in <module>()
# ----> 1 finances = pd.read_csv('finances.csv')
#       2 finances.index = pd.period_range(start='1979-01', end='2016-10', freq='Q-SEP')[:84]
#       3 finances.head()
#
# //anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     643                     skip_blank_lines=skip_blank_lines)
#     644
# --> 645         return _read(filepath_or_buffer, kwds)
#     646
#     647     parser_f.__name__ = name
#
# //anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     386
#     387     # Create the parser.
# --> 388     parser = TextFileReader(filepath_or_buffer, **kwds)
#     389
#     390     if (nrows is not None) and (chunksize is not None):
#
# //anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     727             self.options['has_index_names'] = kwds['has_index_names']
#     728
# --> 729         self._make_engine(self.engine)
#     730
#     731     def close(self):
#
# //anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     920     def _make_engine(self, engine='c'):
#     921         if engine == 'c':
# --> 922             self._engine = CParserWrapper(self.f, **self.options)
#     923         else:
#     924             if engine == 'python':
#
# //anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1387         kwds['allow_leading_cols'] = self.index_col is not False
#    1388
# -> 1389         self._reader = _parser.TextReader(src, **kwds)
#    1390
#    1391         # XXX
#
# pandas/parser.pyx in pandas.parser.TextReader.__cinit__ (pandas/parser.c:4175)()
#
# pandas/parser.pyx in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:8440)()
#
# IOError: File finances.csv does not exist

# %% [markdown]
# ## Problem 5

# %%
website = pd.read_csv('website_traffic.csv')
website.head()
website['ENTER'] = pd.to_datetime(website['ENTER'])
website['LEAVE'] = pd.to_datetime(website['LEAVE'])
website['Duration'] = website['LEAVE'] - website['ENTER']

# %%
print "The average visit time is: {}".format(website['Duration'].mean())
# Out:
# The average visit time is: 0 days 00:05:04.731647

# %%
website.index = pd.to_datetime(website['ENTER'])
website.resample('1H', how = 'count')['ENTER'].head()
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).count()
#   from ipykernel import kernelapp as app
# ENTER
# 2016-10-07 01:00:00    618
# 2016-10-07 02:00:00    655
# 2016-10-07 03:00:00    670
# 2016-10-07 04:00:00    632
# 2016-10-07 05:00:00    672
# Freq: H, Name: ENTER, dtype: int64

# %% [markdown]
# ## Problem 6

# %%
day_gain = DJIA - DJIA.shift(1)
month_val = DJIA.resample('MS', label='left').first()
month_gain = month_val - month_val.shift(1)
day_gain = day_gain.fillna(0)
month_gain = month_gain.fillna(0)

print "The day with the largest gain: {}".format(day_gain.idxmax())
print "The day with the largest loss: {}".format(day_gain.idxmin())
print "The month with the largest gain: {}".format(month_gain.idxmax())
print "The month with the largest loss: {}".format(month_gain.idxmin())
# Out:
# The day with the largest gain: 2008-10-13 00:00:00
# The day with the largest loss: 2008-09-29 00:00:00
# The month with the largest gain: 2015-11-01 00:00:00
# The month with the largest loss: 2015-09-01 00:00:00

# %% [markdown]
# ## Problem 7

# %%
ax = plt.gca()
pd.rolling_mean(DJIA, window=30, min_periods=1).plot(ax=ax, figsize=(19,10))
pd.rolling_mean(DJIA, window=365, min_periods=1).plot(ax=ax)
pd.ewma(DJIA, span=30).plot(ax=ax)
pd.ewma(DJIA, span=365).plot(ax=ax)
ax.legend(["Rolling Avg: 30", "Rolling Avg: 365","EWMA: 30","EWMA: 365"], loc=2)
plt.title("Dow Jones Industrial Average")
plt.xlabel("Date")
plt.ylabel("Amount")
plt.show()
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(min_periods=1,window=30,center=False).mean()
#   from ipykernel import kernelapp as app
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(min_periods=1,window=365,center=False).mean()
#   app.launch_new_instance()
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(ignore_na=False,span=30,min_periods=0,adjust=True).mean()
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(ignore_na=False,span=365,min_periods=0,adjust=True).mean()
